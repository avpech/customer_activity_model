# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Данные-о-поведении-покупателей-(customer_df)" data-toc-modified-id="Данные-о-поведении-покупателей-(customer_df)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Данные о поведении покупателей (customer_df)</a></span></li><li><span><a href="#Данные-о-выручке-(gain_df)" data-toc-modified-id="Данные-о-выручке-(gain_df)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Данные о выручке (gain_df)</a></span></li><li><span><a href="#Данные-о-времени-на-сайте-(time_df)" data-toc-modified-id="Данные-о-времени-на-сайте-(time_df)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Данные о времени на сайте (time_df)</a></span></li><li><span><a href="#Данные-о-прибыли-(income_df)" data-toc-modified-id="Данные-о-прибыли-(income_df)-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Данные о прибыли (income_df)</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Покупательская-активность" data-toc-modified-id="Покупательская-активность-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Покупательская активность</a></span></li><li><span><a href="#Тип-сервиса" data-toc-modified-id="Тип-сервиса-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Тип сервиса</a></span></li><li><span><a href="#Разрешение-на-получение-сообщений" data-toc-modified-id="Разрешение-на-получение-сообщений-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Разрешение на получение сообщений</a></span></li><li><span><a href="#Среднемесячное-кол-во-коммуникаций-за-последние-6-месяцев" data-toc-modified-id="Среднемесячное-кол-во-коммуникаций-за-последние-6-месяцев-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Среднемесячное кол-во коммуникаций за последние 6 месяцев</a></span></li><li><span><a href="#Количество-коммуникаций-в-текущем-месяце" data-toc-modified-id="Количество-коммуникаций-в-текущем-месяце-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Количество коммуникаций в текущем месяце</a></span></li><li><span><a href="#Длительность-(кол-во-дней-с-момента-регистрации)" data-toc-modified-id="Длительность-(кол-во-дней-с-момента-регистрации)-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Длительность (кол-во дней с момента регистрации)</a></span></li><li><span><a href="#Акционные-покупки" data-toc-modified-id="Акционные-покупки-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Акционные покупки</a></span></li><li><span><a href="#Популярная-категория" data-toc-modified-id="Популярная-категория-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Популярная категория</a></span></li><li><span><a href="#Средний-просмотр-категорий-за-визит" data-toc-modified-id="Средний-просмотр-категорий-за-визит-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Средний просмотр категорий за визит</a></span></li><li><span><a href="#Неоплаченные-товары" data-toc-modified-id="Неоплаченные-товары-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Неоплаченные товары</a></span></li><li><span><a href="#Ошибка-сервиса" data-toc-modified-id="Ошибка-сервиса-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>Ошибка сервиса</a></span></li><li><span><a href="#Среднее-количество-просмотренных-страниц" data-toc-modified-id="Среднее-количество-просмотренных-страниц-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>Среднее количество просмотренных страниц</a></span></li><li><span><a href="#Сумма-выручки" data-toc-modified-id="Сумма-выручки-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>Сумма выручки</a></span></li><li><span><a href="#Время-на-сайте" data-toc-modified-id="Время-на-сайте-3.14"><span class="toc-item-num">3.14&nbsp;&nbsp;</span>Время на сайте</a></span></li><li><span><a href="#Прибыль-продавца" data-toc-modified-id="Прибыль-продавца-3.15"><span class="toc-item-num">3.15&nbsp;&nbsp;</span>Прибыль продавца</a></span></li><li><span><a href="#Активность-клиентов" data-toc-modified-id="Активность-клиентов-3.16"><span class="toc-item-num">3.16&nbsp;&nbsp;</span>Активность клиентов</a></span></li></ul></li><li><span><a href="#Объединение-таблиц" data-toc-modified-id="Объединение-таблиц-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Объединение таблиц</a></span></li><li><span><a href="#Корреляционный-анализ" data-toc-modified-id="Корреляционный-анализ-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Корреляционный анализ</a></span></li><li><span><a href="#Построение-пайплайнов" data-toc-modified-id="Построение-пайплайнов-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Построение пайплайнов</a></span></li><li><span><a href="#Анализ-важности-признаков" data-toc-modified-id="Анализ-важности-признаков-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Анализ важности признаков</a></span></li><li><span><a href="#Сегментация-покупателей" data-toc-modified-id="Сегментация-покупателей-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Сегментация покупателей</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Обучение моделей предсказания снижения покупательской активности

# %% [markdown]
# **Описание**: Интернет-магазин «В один клик» продаёт разнобразные товары. Поскольку привлечение новых клиентов уже менее эффективно из-за известности магазина, возникает задача удержания постоянных клиентов с помощью персонализованных предложений. Для этого необходимо на основе имеющихся данных предсказывать снижение покупательской активности у каждого покупателя.

# %% [markdown]
# **Цель:** Обучение модели для прогноза снижения покупательской активности

# %% [markdown]
# **Задачи**:
# - обучить несколько моделей предсказания снижения покупательской активности и выбрать наилучшую
# - интерпретировать признаки
# - сегментировать покупателей
# - провести анализ для одного из сегментов

# %% [markdown]
# **Исходные данные:**
#
# `market_file.csv` - данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
# - id — номер покупателя в корпоративной базе данных.
# - Покупательская активность — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# - Тип сервиса — уровень сервиса, например «премиум» и «стандарт». Зависит от наличия определенной подписки у пользователя.
# - Разрешить сообщать — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# - Маркет_актив_6_мес — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# - Маркет_актив_тек_мес — количество маркетинговых коммуникаций в текущем месяце.
# - Длительность — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# - Акционные_покупки — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# - Популярная_категория — самая популярная категория товаров у покупателя за последние 6 месяцев.
# - Средний_просмотр_категорий_за_визит — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# - Неоплаченные_продукты_штук_квартал — общее число неоплаченных товаров в корзине за последние 3 месяца.
# - Ошибка_сервиса — число сбоев, которые коснулись покупателя во время посещения сайта за последние 3 месяца.
# - Страниц_за_визит — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
# `market_money.csv` - данные о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
# - id — номер покупателя в корпоративной базе данных.
# - Период — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
# - Выручка — сумма выручки за период в условных единицах.
#
# `market_time.csv` - данные о времени (в минутах), которое покупатель провёл на сайте в течение периода.
# - id — номер покупателя в корпоративной базе данных.
# - Период — название периода, во время которого зафиксировано общее время.
# - минут — значение времени, проведённого на сайте, в минутах.
#
# `money.csv` - данные о среднемесячной прибыли продавца за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
# - id — номер покупателя в корпоративной базе данных.
# - Прибыль — значение прибыли в условных единицах.

# %%
# !pip install -U scikit-learn -q
# !pip install phik -q
# !pip install shap -q

# %%
import os
import re
from typing import Optional

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import phik
import seaborn as sns
import shap
import warnings
from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyClassifier
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, precision_score, recall_score, roc_auc_score
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, OrdinalEncoder, PolynomialFeatures, StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from IPython.display import display, HTML, Markdown

warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# Создадим вспомогательные фукнции для импорта и просмотра данных

# %%
def to_snake_case(df: pd.DataFrame) -> pd.DataFrame:
    df.columns = df.columns.str.strip().str.replace(' ', '_').str.lower()
    return df

# %%
PATH_PREFIXES = ('/datasets', 'https://code.s3.yandex.net/datasets', './datasets')

def import_df(table_name: str, sep: str = ';', decimal: str = '.') -> pd.DataFrame:
    for path_prefix in PATH_PREFIXES:
        try:
            return to_snake_case(pd.read_csv(os.path.join(path_prefix, table_name), sep=sep, decimal=decimal))
        except Exception:
            continue
    print(f'File {table_name} not found')

# %%
def df_info(df: pd.DataFrame) -> None:
    display(Markdown('**Размер датафрейма**'), df.shape)
    display(Markdown('**Информация о датафрейме**'))
    df.info()
    display(Markdown(f'**Количество явных дубликатов строк: {df.duplicated().sum()}**'))
    display(Markdown(f'**Общее количество пропущенных значений: {df.isna().sum().sum()}**'))
    display(Markdown('**Первые строки датафрейма**'), df.head())

# %% [markdown]
# Импортируем данные о покупателях

# %%
customer_df = import_df('market_file.csv', sep=',')

# %%
df_info(customer_df)
# Out:
# **Размер датафрейма**
# (1300, 13)
# **Информация о датафрейме**
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   покупательская_активность            1300 non-null   object
#  2   тип_сервиса                          1300 non-null   object
#  3   разрешить_сообщать                   1300 non-null   object
#  4   маркет_актив_6_мес                   1300 non-null   float64
#  5   маркет_актив_тек_мес                 1300 non-null   int64
#  6   длительность                         1300 non-null   int64
#  7   акционные_покупки                    1300 non-null   float64
#  8   популярная_категория                 1300 non-null   object
#  9   средний_просмотр_категорий_за_визит  1300 non-null   int64
# ...

# %% [markdown]
# Импортируем данные о выручке

# %%
gain_df = import_df('market_money.csv', sep=',')

# %%
df_info(gain_df)
# Out:
# **Размер датафрейма**
# (3900, 3)
# **Информация о датафрейме**
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   период   3900 non-null   object
#  2   выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB
# **Количество явных дубликатов строк: 0**
# **Общее количество пропущенных значений: 0**
# **Первые строки датафрейма**
#        id               период  выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6

# %% [markdown]
# Импортируем данные о времени на сайте

# %%
time_df = import_df('market_time.csv', sep=',')

# %%
df_info(time_df)
# Out:
# **Размер датафрейма**
# (2600, 3)
# **Информация о датафрейме**
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB
# **Количество явных дубликатов строк: 0**
# **Общее количество пропущенных значений: 0**
# **Первые строки датафрейма**
#        id            период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13

# %% [markdown]
# Импортируем данные о прибыли продавца

# %%
income_df = import_df('money.csv', decimal=',')

# %%
df_info(income_df)
# Out:
# **Размер датафрейма**
# (1300, 2)
# **Информация о датафрейме**
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB
# **Количество явных дубликатов строк: 0**
# **Общее количество пропущенных значений: 0**
# **Первые строки датафрейма**
#        id  прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %% [markdown]
# <strong>
#
# В данных о поведении покупателя 1300 строк.
#
# В данных о выручке 3900 строк.
#
# В данных о времени на сайте 2600 строк.
#
# В данных о прибыли продавца 1300 строк.
#
# Пропущенных значений и явных дубликатов строк не выявлено ни в одной из таблиц. Названия колонок были приведены к `snake_case` при импорте данных. Типы данных корректны.
#
# Также при первичном осмотре можно заметить неявные дубликаты, которые будут изучены более подробно на этапе предобработки. Следует обратить внимание, что в данных о времени на сайте и выручке содержится по неколько записей для каждого клиента за разные периоды.
# </strong>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Создадим вспомогательную фукнцию для просмотра уникальных значений колонок

# %%
def show_unique_columns_values(df: pd.DataFrame, cols: list[str]) -> None:
    for col in cols:
        if col in df.columns:
            print(f'\n{col}: {df[col].unique().tolist()}')
        else:
            print(f'\n{col}: колонка отсутствует в датафрейме')

# %% [markdown]
# ### Данные о поведении покупателей (customer_df)

# %%
df_info(customer_df)
# Out:
# **Размер датафрейма**
# (1300, 13)
# **Информация о датафрейме**
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   покупательская_активность            1300 non-null   object
#  2   тип_сервиса                          1300 non-null   object
#  3   разрешить_сообщать                   1300 non-null   object
#  4   маркет_актив_6_мес                   1300 non-null   float64
#  5   маркет_актив_тек_мес                 1300 non-null   int64
#  6   длительность                         1300 non-null   int64
#  7   акционные_покупки                    1300 non-null   float64
#  8   популярная_категория                 1300 non-null   object
#  9   средний_просмотр_категорий_за_визит  1300 non-null   int64
# ...

# %% [markdown]
# Изучим категориальные колонки на наличие неявных дубликатов

# %%
cat_cols_names = [
    'покупательская_активность',
    'тип_сервиса',
    'разрешить_сообщать',
    'популярная_категория',
]

# %%
show_unique_columns_values(customer_df, cat_cols_names)
# Out:
# покупательская_активность: ['Снизилась', 'Прежний уровень']
#
# тип_сервиса: ['премиум', 'стандартт', 'стандарт']
#
# разрешить_сообщать: ['да', 'нет']
#
# популярная_категория: ['Товары для детей', 'Домашний текстиль', 'Косметика и аксесуары', 'Техника для красоты и здоровья', 'Кухонная посуда', 'Мелкая бытовая техника и электроника']

# %% [markdown]
# Обнаружен неявный дубликат в колонке `тип_сервиса`. Устраним.

# %%
customer_df['тип_сервиса'] = customer_df['тип_сервиса'].replace('стандартт', 'стандарт')
customer_df['тип_сервиса'].unique().tolist()
# Out:
# ['премиум', 'стандарт']

# %% [markdown]
# Убедимся в отсутствии дубликатов в `id`

# %%
customer_df['id'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Убедимся, что после устранения неявных дубликатов не образовалось явных дубликатов строк

# %%
customer_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Данные о выручке (gain_df)

# %%
df_info(gain_df)
# Out:
# **Размер датафрейма**
# (3900, 3)
# **Информация о датафрейме**
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   период   3900 non-null   object
#  2   выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB
# **Количество явных дубликатов строк: 0**
# **Общее количество пропущенных значений: 0**
# **Первые строки датафрейма**
#        id               период  выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6

# %% [markdown]
# Изучим категориальную колонку на наличие неявных дубликатов

# %%
show_unique_columns_values(gain_df, ['период'])
# Out:
# период: ['препредыдущий_месяц', 'текущий_месяц', 'предыдущий_месяц']

# %% [markdown]
# Убедимся, что отсутствют дубликаты записей для пользователей для каждого периода

# %%
gain_df[['id', 'период']].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Данные о времени на сайте (time_df)

# %%
df_info(time_df)
# Out:
# **Размер датафрейма**
# (2600, 3)
# **Информация о датафрейме**
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB
# **Количество явных дубликатов строк: 0**
# **Общее количество пропущенных значений: 0**
# **Первые строки датафрейма**
#        id            период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13

# %% [markdown]
# Изучим категориальную колонку на наличие неявных дубликатов

# %%
show_unique_columns_values(time_df, ['период'])
# Out:
# период: ['текущий_месяц', 'предыдцщий_месяц']

# %% [markdown]
# Обнаружен неявный дубликат относительно данных в таблице `gain_df`. Устраним.

# %%
time_df['период'] = time_df['период'].replace('предыдцщий_месяц', 'предыдущий_месяц')
time_df['период'].unique().tolist()
# Out:
# ['текущий_месяц', 'предыдущий_месяц']

# %% [markdown]
# Убедимся, что отсутствуют дубликаты записей для пользователей для каждого периода

# %%
time_df[['id', 'период']].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Данные о прибыли (income_df)

# %%
df_info(income_df)
# Out:
# **Размер датафрейма**
# (1300, 2)
# **Информация о датафрейме**
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB
# **Количество явных дубликатов строк: 0**
# **Общее количество пропущенных значений: 0**
# **Первые строки датафрейма**
#        id  прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %% [markdown]
# Убедимся в отсутствии дубликатов в `id`

# %%
income_df['id'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **В ходе предобработки данных были выявлены и устранены неявные дубликаты в колонках `тип_сервиса` таблицы `customer_df` и `период` таблицы `time_df`**
#
# **Явные дубликаты и пропуски в данных отсутствуют**

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Создадим вспомогательные функции для построения графиков

# %%
def draw_hist(
    values: pd.Series,
    title: str,
    xlabel: str,
    bins: int = 30,
    figsize: tuple[int, int] = (10, 6),
) -> None:
    plt.figure(figsize=figsize)
    plt.hist(values, bins=bins)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel('Количество клиентов')
    plt.show()

# %%
def draw_boxplot(
    values: pd.Series,
    title: str,
    ylabel: str,
    figsize: tuple[int, int] = (10, 6),
) -> None:
    plt.figure(figsize=figsize)
    plt.boxplot(values)
    plt.title(title)
    plt.ylabel(ylabel)
    plt.show()

# %%
def draw_bar(
    values: pd.Series,
    title: str,
    label: str,
    figsize: tuple[int, int] = (10, 6),
    ascending: Optional[bool] = None,
    horizontal: bool = False,
) -> None:
    counts = values.value_counts().sort_index()
    if ascending:
        counts = counts.sort_values(ascending=ascending)
    plt.figure(figsize=figsize)
    if horizontal:
        plt.barh(counts.index.astype(str), counts.values)
        plt.xlabel('Количество клиентов')
        plt.ylabel(label)
    else:
        plt.bar(counts.index.astype(str), counts.values)
        plt.xlabel(label)
        plt.ylabel('Количество клиентов')
    plt.title(title)
    plt.show()

# %% [markdown]
# ### Покупательская активность

# %% [markdown]
# Изучим содежимое колонки с информацией о покупательской активности

# %%
draw_bar(
    customer_df['покупательская_активность'],
    title='Распределение по покупательской активности',
    label='Покупательская активность',
)

# %% [markdown]
# Покупательская активость является целевым признаком, делаем вывод о его несбалансированности

# %% [markdown]
# ### Тип сервиса

# %% [markdown]
# Изучим содежимое колонки с информацией о типе сервиса

# %%
draw_bar(
    customer_df['тип_сервиса'],
    title='Распределение по типу сервиса',
    label='Тип сервиса',
)

# %% [markdown]
# Наблюдаем преобладание пользователей без премиум подписки

# %% [markdown]
# ### Разрешение на получение сообщений

# %% [markdown]
# Изучим содержимое колонки с информацией о разрешении на получение сообщений

# %%
draw_bar(
    customer_df['разрешить_сообщать'],
    title='Распределение по разрешению на получение сообщений',
    label='Разрешение на получение сообщений',
)

# %% [markdown]
# Преобладают клиенты, дающие согласие на получение сообщений с дополнительными предложениями

# %% [markdown]
# ### Среднемесячное кол-во коммуникаций за последние 6 месяцев

# %% [markdown]
# Изучим содержимое колонки с информацией о среднемесячном количестве коммуникаций за последние 6 месяцев

# %%
customer_df['маркет_актив_6_мес'].describe()
# Out:
# count    1300.000000
# mean        4.253769
# std         1.014814
# min         0.900000
# 25%         3.700000
# 50%         4.200000
# 75%         4.900000
# max         6.600000
# Name: маркет_актив_6_мес, dtype: float64

# %%
draw_hist(
    customer_df['маркет_актив_6_мес'],
    title='Распределение среднемесячного кол-ва коммуникаций',
    xlabel='Среднемесячное кол-во коммуникаций',
    bins=20
)

# %%
draw_boxplot(
    customer_df['маркет_актив_6_мес'],
    title='Boxplot среднемесячного кол-ва коммуникаций',
    ylabel='Среднемесячное кол-во коммуникаций'
)

# %% [markdown]
# Преобладащее коичество коммуникаций с клиентами составляет 3-6 в месяц. Среднее и медианное значения составляют около 4 коммуникаций в месяц. Можно видеть несколько не являющихся аномальными выбросов с малым количеством коммуникаций (вероятно, объясняются тем, что эти клиенты пользуются сервисом менее 6 месяцев)

# %% [markdown]
# ### Количество коммуникаций в текущем месяце

# %% [markdown]
# Изучим содержимое колонки с информацией о количестве коммуникаций в текущем месяце

# %%
customer_df['маркет_актив_тек_мес'].describe()
# Out:
# count    1300.000000
# mean        4.011538
# std         0.696868
# min         3.000000
# 25%         4.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: маркет_актив_тек_мес, dtype: float64

# %%
draw_bar(
    customer_df['маркет_актив_тек_мес'],
    title='Распределение по количеству коммуникаций в текущем месяце',
    label='Количество коммуникаций',
)

# %% [markdown]
# Количество коммуникаций в текущем месяце колеблется в диапазоне от 3 до 5, преобладает 4 коммуникации в месяц на клиента

# %% [markdown]
# ### Длительность (кол-во дней с момента регистрации)

# %% [markdown]
# Изучим содержимое колонки с информацией о количестве дней с момента регистрации покупателя

# %%
customer_df['длительность'].describe()
# Out:
# count    1300.000000
# mean      601.898462
# std       249.856289
# min       110.000000
# 25%       405.500000
# 50%       606.000000
# 75%       806.000000
# max      1079.000000
# Name: длительность, dtype: float64

# %%
draw_hist(
    customer_df['длительность'],
    title='Распределение количества дней с момента регистрации',
    xlabel='Количество дней с момента регистрации',
    bins=20
)

# %%
draw_boxplot(
    customer_df['длительность'],
    title='Boxplot количества дней с момента регистрации',
    ylabel='Количество дней с момента регистрации'
)

# %% [markdown]
# Выбросов и аномальных значений не наблюдается. Минимально наблюдаемое количество дней с момента регистрации составляет 110 дней: объясняется тем, что в выборку сознательно включили только покупателей, зарегистрировавшихся более 3 месяцев назад

# %% [markdown]
# ### Акционные покупки

# %% [markdown]
# Изучим содержимое колонки с информацией о среднемесячной доле покупок, совершенных по акции

# %%
customer_df['акционные_покупки'].describe()
# Out:
# count    1300.000000
# mean        0.319808
# std         0.249843
# min         0.000000
# 25%         0.170000
# 50%         0.240000
# 75%         0.300000
# max         0.990000
# Name: акционные_покупки, dtype: float64

# %%
draw_hist(
    customer_df['акционные_покупки'],
    title='Распределение по среднемесячной доле покупок по акции',
    xlabel='Доля покупок по акции',
    bins=30
)

# %%
draw_boxplot(
    customer_df['акционные_покупки'],
    title='Boxplot среднемесячной доли покупок по акции',
    ylabel='Доля покупок по акции'
)

# %% [markdown]
# Медиана среднемесячной доли покупок по акции составляет 24%, среднее 32%. Наблюдаем выбросы, которые не являются аномальными - ожидаемо, что некоторые пользователи совершали покупки преимущественно по акции. Заметен сегмент клиентов, совершавших покупки преимущественно по акции.

# %% [markdown]
# ### Популярная категория

# %% [markdown]
# Изучим содержимое колонки с информацией о самой популярной категории товаров у покупателя за последние 6 месяцев

# %%
draw_bar(
    customer_df['популярная_категория'],
    title='Распределение по самым популярным категориям',
    label='Самая популярная категория',
    horizontal=True,
    ascending=True,
)

# %% [markdown]
# ### Средний просмотр категорий за визит

# %% [markdown]
# Изучим содержимое колонки с информацией о том, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца

# %%
customer_df['средний_просмотр_категорий_за_визит'].describe()
# Out:
# count    1300.00000
# mean        3.27000
# std         1.35535
# min         1.00000
# 25%         2.00000
# 50%         3.00000
# 75%         4.00000
# max         6.00000
# Name: средний_просмотр_категорий_за_визит, dtype: float64

# %%
draw_bar(
    customer_df['средний_просмотр_категорий_за_визит'],
    title='Распределение среднего кол-ва категорий за визит',
    label='Среднее кол-во категорий',
)

# %% [markdown]
# Наблюдаем, что пользователи просматривают от 1 до 6 категорий за визит, при этом преобладают просмотры от 2 до 4 категорий

# %% [markdown]
# ### Неоплаченные товары

# %% [markdown]
# Изучим содержимое колонки с информацией о количестве неоплаченных товаров в корзине за последние 3 месяца

# %%
customer_df['неоплаченные_продукты_штук_квартал'].describe()
# Out:
# count    1300.000000
# mean        2.840000
# std         1.971451
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: неоплаченные_продукты_штук_квартал, dtype: float64

# %%
draw_bar(
    customer_df['неоплаченные_продукты_штук_квартал'],
    title='Распределение количества неоплаченных товаров в корзине',
    label='Кол-во неоплаченных товаров',
)

# %%
draw_boxplot(
    customer_df['неоплаченные_продукты_штук_квартал'],
    title='Boxplot количества неоплаченных товаров в корзине',
    ylabel='Кол-во неоплаченных товаров'
)

# %% [markdown]
# Наблюдаем малое количество выбросов. Медианное значение количества неоплаченных товаров составляет 3 штуки.

# %% [markdown]
# ### Ошибка сервиса

# %% [markdown]
# Изучим содержимое колонки с информацией о числе сбоев, которые коснулись покупателя во время посещения сайта за последние 3 месяца.

# %%
customer_df['ошибка_сервиса'].describe()
# Out:
# count    1300.000000
# mean        4.185385
# std         1.955298
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         6.000000
# max         9.000000
# Name: ошибка_сервиса, dtype: float64

# %%
draw_bar(
    customer_df['ошибка_сервиса'],
    title='Распределение количества сбоев',
    label='Кол-во сбоев',
)

# %%
draw_boxplot(
    customer_df['ошибка_сервиса'],
    title='Boxplot количества сбоев',
    ylabel='Кол-во сбоев'
)

# %% [markdown]
# Распределение количества сбоев имеет ожидаемо похожее на нормальное распределение. В среднем клиенты сталкивались с 4 сбоями за квартал

# %% [markdown]
# ### Среднее количество просмотренных страниц

# %% [markdown]
# Изучим содержимое колонки с информацией о среднем количестве страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.

# %%
customer_df['страниц_за_визит'].describe()
# Out:
# count    1300.000000
# mean        8.176923
# std         3.978126
# min         1.000000
# 25%         5.000000
# 50%         8.000000
# 75%        11.000000
# max        20.000000
# Name: страниц_за_визит, dtype: float64

# %%
draw_bar(
    customer_df['страниц_за_визит'],
    title='Распределение количества страниц за визит',
    label='Кол-во страниц',
)

# %%
draw_boxplot(
    customer_df['страниц_за_визит'],
    title='Boxplot количества страниц за визит',
    ylabel='Кол-во страниц'
)

# %% [markdown]
# В среднем пользователи просматривали 8 страниц за визит. Выбросов и аномальных значений не наблюдается.

# %% [markdown]
# ### Сумма выручки

# %% [markdown]
# Изучим содержимое датафрейма с суммами выручки

# %%
for period in gain_df['период'].unique():
    print(f'Период: {period}')
    display(gain_df.loc[gain_df['период'] == period, 'выручка'].describe())
# Out:
# Период: препредыдущий_месяц
# count    1300.000000
# mean     4825.206923
# std       405.979663
# min         0.000000
# 25%      4583.000000
# 50%      4809.000000
# 75%      5053.500000
# max      5663.000000
# Name: выручка, dtype: float64
# Период: текущий_месяц
# count      1300.000000
# mean       5314.960846
# std        2939.708156
# min        2758.700000
# 25%        4706.050000
# 50%        5179.950000
# 75%        5761.725000
# max      106862.200000
# Name: выручка, dtype: float64
# Период: предыдущий_месяц
# count    1300.000000
# mean     4936.920385
# std       739.597997
# min         0.000000
# 25%      4496.750000
# 50%      5005.000000
# 75%      5405.625000
# max      6869.500000
# Name: выручка, dtype: float64

# %%
axes = gain_df.hist(column='выручка', by='период', bins=30, figsize=(15, 12))
for ax in axes.flatten():
    ax.set_xlabel('Сумма выручки, у.е.')
    ax.set_ylabel('Количество клиентов')
plt.show()

# %%
ax = gain_df.boxplot(column='выручка', by='период', figsize=(15, 12))
plt.suptitle('')
plt.title('Boxplot сумм выручки в разные периоды')
ax.set_xlabel('Период')
ax.set_ylabel('Сумма выручки, у.е.')
plt.show()

# %% [markdown]
# Наблюдаем выбросы, особенно примечателен выброс с суммой выручки более 100000 у.е. в текущем месяце. Однако нет оснований считать их аномальными. Тем не менее, единичный выброс со значением более 100000 у.е. негативно отразится на качестве модели, при этом в силу своего единичного характера не позволяя выявить закономерность для подобных значений, поэтому устраним его.

# %%
gain_df = gain_df[
    ~gain_df['id'].isin(
        gain_df.loc[gain_df['выручка'] > 100_000, 'id'].unique()
    )
]

# %% [markdown]
# Повторно изучим информацию после устранения выброса

# %%
for period in gain_df['период'].unique():
    print(f'Период: {period}')
    display(gain_df.loc[gain_df['период'] == period, 'выручка'].describe())
# Out:
# Период: препредыдущий_месяц
# count    1299.000000
# mean     4825.033102
# std       406.087624
# min         0.000000
# 25%      4583.000000
# 50%      4809.000000
# 75%      5054.000000
# max      5663.000000
# Name: выручка, dtype: float64
# Период: текущий_месяц
# count    1299.000000
# mean     5236.787452
# std       835.474686
# min      2758.700000
# 25%      4705.500000
# 50%      5179.600000
# 75%      5759.950000
# max      7799.400000
# Name: выручка, dtype: float64
# Период: предыдущий_месяц
# count    1299.000000
# mean     4936.042725
# std       739.205300
# min         0.000000
# 25%      4496.500000
# 50%      5004.500000
# 75%      5404.250000
# max      6869.500000
# Name: выручка, dtype: float64

# %%
axes = gain_df.hist(column='выручка', by='период', bins=30, figsize=(15, 12))
for ax in axes.flatten():
    ax.set_xlabel('Сумма выручки, у.е.')
    ax.set_ylabel('Количество клиентов')
plt.show()

# %%
ax = gain_df.boxplot(column='выручка', by='период', figsize=(15, 12))
plt.suptitle('')
plt.title('Boxplot сумм выручки в разные периоды')
ax.set_xlabel('Период')
ax.set_ylabel('Сумма выручки, у.е.')
plt.show()

# %% [markdown]
# Наблюдаем, что распределение выручки похоже на нормальное. Также заметен тренд на рост средней и медианной среднемесячной выручки

# %% [markdown]
# ### Время на сайте

# %% [markdown]
# Изучим содержимое датафрейма с временем посетителя на сайте

# %%
axes = time_df.hist(column='минут', by='период', bins=15, figsize=(15, 12))
for ax in axes.flatten():
    ax.set_xlabel('Длительность, минут')
    ax.set_ylabel('Количество клиентов')
plt.show()

# %%
ax = time_df.boxplot(column='минут', by='период', figsize=(15, 12))
plt.suptitle('')
plt.title('Boxplot времени на сайте в разные периоды')
ax.set_xlabel('Период')
ax.set_ylabel('Длительность, минут')
plt.show()

# %% [markdown]
# Выбросов и аномальных значений не наблюдается.

# %% [markdown]
# ### Прибыль продавца

# %% [markdown]
# Изучим содержимое датафрейма с данными о прибыли продавца

# %%
income_df['прибыль'].describe()
# Out:
# count    1300.000000
# mean        3.996631
# std         1.013722
# min         0.860000
# 25%         3.300000
# 50%         4.045000
# 75%         4.670000
# max         7.430000
# Name: прибыль, dtype: float64

# %%
draw_hist(
    income_df['прибыль'],
    title='Распределение прибыли',
    xlabel='Прибыль, у.е.',
    bins=20
)

# %%
draw_boxplot(
    income_df['прибыль'],
    title='Boxplot прибыли',
    ylabel='Прибыль, у.е.'
)

# %% [markdown]
# Наблюдаем похожее на нормальное распределение. В среднем прибыль с одного клиента составляет 4.у.е. в месяц

# %% [markdown]
# ### Активность клиентов

# %% [markdown]
# Отберем клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период. Сначала найдем id клиентов, которые не совершали покупки в какой-то из месяцов

# %%
non_active_clients_ids = gain_df.loc[gain_df['выручка'] == 0, 'id'].unique()
non_active_clients_ids
# Out:
# array([215348, 215357, 215359])

# %% [markdown]
# Исключим их из основного датафрейма с информацией о поведении покупателей

# %%
customer_df = customer_df[~customer_df['id'].isin(non_active_clients_ids)]
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1297 entries, 1 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1297 non-null   int64
#  1   покупательская_активность            1297 non-null   object
#  2   тип_сервиса                          1297 non-null   object
#  3   разрешить_сообщать                   1297 non-null   object
#  4   маркет_актив_6_мес                   1297 non-null   float64
#  5   маркет_актив_тек_мес                 1297 non-null   int64
#  6   длительность                         1297 non-null   int64
#  7   акционные_покупки                    1297 non-null   float64
#  8   популярная_категория                 1297 non-null   object
#  9   средний_просмотр_категорий_за_визит  1297 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1297 non-null   int64
# ...

# %% [markdown]
# <strong>
# Результаты исследовательского анализа:
#
# - Целевой признак несбалансирован (преобладают клиенты, у которых не изменилась покупательская активность)
# - Из основного датафрейма были исключеный 3 клиента, не совершавших ежемесячные покупки в течение трех месяцев
# - В информации о выручке был один чрезвычайно высокий выброс - устранен
# </strong>

# %% [markdown]
# ## Объединение таблиц

# %% [markdown]
# В датафреймах `gain_df` и `time_df` преобразуем категории в колонки

# %%
pivot_gain_df = gain_df.pivot(index='id', columns='период', values='выручка')
pivot_gain_df.head(3)
# Out:
# период  предыдущий_месяц  препредыдущий_месяц  текущий_месяц
# id
# 215348               0.0                  0.0         3293.1
# 215349            5216.0               4472.0         4971.6
# 215350            5457.5               4826.0         5058.4

# %%
pivot_gain_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1299 entries, 215348 to 216647
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   предыдущий_месяц     1299 non-null   float64
#  1   препредыдущий_месяц  1299 non-null   float64
#  2   текущий_месяц        1299 non-null   float64
# dtypes: float64(3)
# memory usage: 40.6 KB

# %%
pivot_time_df = time_df.pivot(index='id', columns='период', values='минут')
pivot_time_df.head(3)
# Out:
# период  предыдущий_месяц  текущий_месяц
# id
# 215348                13             14
# 215349                12             10
# 215350                 8             13

# %%
pivot_time_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1300 entries, 215348 to 216647
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   предыдущий_месяц  1300 non-null   int64
#  1   текущий_месяц     1300 non-null   int64
# dtypes: int64(2)
# memory usage: 30.5 KB

# %% [markdown]
# Объединим датафреймы

# %%
common_df = (
    customer_df.set_index('id')
    .join(pivot_gain_df.add_prefix('выручка_'), how='inner')
    .join(pivot_time_df.add_prefix('минуты_'), how='inner')
)

# %%
common_df.head()
# Out:
#        покупательская_активность тип_сервиса разрешить_сообщать  \
# id
# 215349                 Снизилась     премиум                 да
# 215350                 Снизилась    стандарт                нет
# 215351                 Снизилась    стандарт                 да
# 215352                 Снизилась    стандарт                нет
# 215353                 Снизилась    стандарт                 да
#
#         маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# id
# 215349                 4.4                     4           819
# 215350                 4.9                     3           539
# 215351                 3.2                     5           896
# 215352                 5.1                     3          1064
# 215353                 3.3                     4           762
#
#         акционные_покупки популярная_категория  \
# id
# 215349               0.75     Товары для детей
# 215350               0.14    Домашний текстиль
# ...

# %%
common_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1296 entries, 215349 to 216647
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   покупательская_активность            1296 non-null   object
#  1   тип_сервиса                          1296 non-null   object
#  2   разрешить_сообщать                   1296 non-null   object
#  3   маркет_актив_6_мес                   1296 non-null   float64
#  4   маркет_актив_тек_мес                 1296 non-null   int64
#  5   длительность                         1296 non-null   int64
#  6   акционные_покупки                    1296 non-null   float64
#  7   популярная_категория                 1296 non-null   object
#  8   средний_просмотр_категорий_за_визит  1296 non-null   int64
#  9   неоплаченные_продукты_штук_квартал   1296 non-null   int64
#  10  ошибка_сервиса                       1296 non-null   int64
# ...

# %% [markdown]
# **В результате объединения датафреймов с информацией о поведении покупателей, выручке и времени на сайте не возникло пропущенных значений**

# %% [markdown]
# ## Корреляционный анализ

# %% [markdown]
# Построим матрицу корреляций

# %%
corr_matrix = common_df.phik_matrix(
    interval_cols=[
        'маркет_актив_6_мес', 'акционные_покупки', 'выручка_предыдущий_месяц',
        'выручка_препредыдущий_месяц', 'выручка_текущий_месяц'
    ]
)
corr_matrix
# Out:
#                                      покупательская_активность  тип_сервиса  \
# покупательская_активность                             1.000000     0.129940
# тип_сервиса                                           0.129940     1.000000
# разрешить_сообщать                                    0.000000     0.289965
# маркет_актив_6_мес                                    0.544831     0.089911
# маркет_актив_тек_мес                                  0.000000     0.045258
# длительность                                          0.000000     0.611909
# акционные_покупки                                     0.506276     0.030010
# популярная_категория                                  0.299717     0.070809
# средний_просмотр_категорий_за_визит                   0.539607     0.185391
# неоплаченные_продукты_штук_квартал                    0.405041     0.113015
# ошибка_сервиса                                        0.224154     0.079515
# ...

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Матрица корреляции (Phi_K)')
plt.show()

# %% [markdown]
# **Мультиколлинеарность отсутствует. Целевой признак имеет крайне низкую корреляцию с признаками `разрешить_сообщать`, `маркет_актив_тек_мес` и `длительность`. Возможно, имеет смысл исключить эти признаки**

# %% [markdown]
# ## Построение пайплайнов

# %% [markdown]
# Построим пайплайн для поиска наилучшей модели. Поскольку мы не располагаем информацией о том, является ли для заказчика предпочтительным не упустить клиентов с потеницально снизившейся активностью или же не делать персонализованные предложения активным клиентам, то в качестве метрики будем использовать ROC AUC для общей оценки качества модели.

# %%
RANDOM_STATE = 42
TEST_SIZE = 0.25

# %%
X_train, X_test, y_train, y_test = train_test_split(
    common_df.drop('покупательская_активность', axis=1),
    common_df['покупательская_активность'],
    test_size=TEST_SIZE,
    random_state = RANDOM_STATE,
    stratify=common_df['покупательская_активность'],
)
X_train.shape, X_test.shape
# Out:
# ((972, 16), (324, 16))

# %%
ohe_columns = ['тип_сервиса']
ord_columns = ['популярная_категория', 'разрешить_сообщать']

# %%
num_columns = [
    'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность', 'акционные_покупки',
    'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал',
    'ошибка_сервиса', 'страниц_за_визит', 'выручка_предыдущий_месяц', 'выручка_препредыдущий_месяц',
    'выручка_текущий_месяц', 'минуты_предыдущий_месяц', 'минуты_текущий_месяц'
]
ohe_columns_for_linear = ['тип_сервиса', 'популярная_категория']
ord_columns_for_linear = ['разрешить_сообщать']

# %%
ohe_pipe = Pipeline(
    [
        ('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
        ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]
)

# %%
ord_pipe = Pipeline(
    [
        ('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
        ('ord', OrdinalEncoder(
            categories=[
                [
                    'Товары для детей', 'Домашний текстиль', 'Косметика и аксесуары',
                    'Техника для красоты и здоровья', 'Кухонная посуда', 'Мелкая бытовая техника и электроника'
                ],
                ['нет', 'да'],
            ],
            handle_unknown='use_encoded_value', unknown_value=np.nan)
        ),
        ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)
ord_pipe_for_linear = Pipeline(
    [
        ('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
        ('ord', OrdinalEncoder(
            categories=[['нет', 'да']],
            handle_unknown='use_encoded_value', unknown_value=np.nan)
        ),
        ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns),
        ('ord', ord_pipe, ord_columns),
        ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

data_preprocessor_for_linear = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns_for_linear),
        ('ord', ord_pipe_for_linear, ord_columns_for_linear),
        ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

param_grid = [
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 20),
        'models__max_features': range(2, 16),
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]  
    },
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]   
    },
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE,
            max_iter=1000,
            solver='liblinear', 
        )],
        'models__solver': ['liblinear', 'saga'],
        'models__penalty': ['l1', 'l2'],
        'models__C': [0.1, 0.5, 0.7, 1, 3, 5],
        'preprocessor': [data_preprocessor_for_linear],
        'preprocessor__num': [StandardScaler(), MinMaxScaler()],
    },
    {
        'models': [SVC(
            random_state=RANDOM_STATE,
            probability=True
        )],
        'models__kernel': ['linear', 'poly'],
        'models__C': [0.1, 0.5, 0.7, 1, 3, 5],
        'models__degree': [2],
        'preprocessor': [data_preprocessor_for_linear],
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]
    }
]

# %%
grid_search = GridSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    n_jobs=-1
)
grid_search.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', grid_search.best_estimator_)
print ('Метрика лучшей модели на кросс-валидации:', grid_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['тип_сервиса',
#                                                    'популярная_категория']),
#                                                  ('ord',
# ...

# %%
grid_search.best_estimator_.get_params()['models__penalty']
# Out:
# 'l2'

# %%
y_test_proba = grid_search.predict_proba(X_test)[:, 1]
y_pred = grid_search.predict(X_test)
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_test_proba)}')
print(f'Метрика precision на тестовой выборке: {precision_score(y_test, y_pred, pos_label="Снизилась")}')
print(f'Метрика recall на тестовой выборке: {recall_score(y_test, y_pred, pos_label="Снизилась")}')
cm = confusion_matrix(y_test, grid_search.predict(X_test))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues_r')
plt.ylabel('True label')
plt.xlabel('Predicted')
plt.show()
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.9205598026129516
# Метрика precision на тестовой выборке: 0.98
# Метрика recall на тестовой выборке: 0.7967479674796748

# %% [markdown]
# Видим, что метрика ROC-AUC на тестовой выборке составила 0.92.
#
# Модель верно предсказала снижение аткивности 98 клиентов и сохранение прежнего уровня активности 199 клиентов.
#
# У 2 клиентов было ошибочно предсказано снижение активности, еще у 25 клиентов ошибочно был предсказан прежний уровень активности.
#
# Видим, что у модели преобладают ложноотрицательные ошибки: то есть она редко делает ошибочные предсказания о снижении уровня активности, при этом значительно чаще ошибается в предсказаниях сохранения прежнего уровня активности клиентов.

# %% [markdown]
# Для сравнения посмотрим на ROC AUC метрику Dummy модели

# %%
dummy = DummyClassifier(strategy='stratified', random_state=RANDOM_STATE)
dummy.fit(X_train, y_train)

y_pred_proba = dummy.predict_proba(X_test)[:, 1]

auc = roc_auc_score(y_test, y_pred_proba)

print(f'Метрика ROC-AUC дамми модели: {roc_auc_score(y_test, y_pred_proba)}')
# Out:
# Метрика ROC-AUC дамми модели: 0.4945394976337823

# %% [markdown]
# **Лучше всего себя показала модель логистической регрессии с L2 регуляризацией. Метрика ROC AUC на тестовой выборке составила 0.92**
#
# **Модель верно предсказала снижение аткивности 98 клиентов и сохранение прежнего уровня активности 199 клиентов.**
#
# **У 2 клиентов было ошибочно предсказано снижение активности, еще у 25 клиентов ошибочно был предсказан прежний уровень активности.**
#
# **Видим, что у модели преобладают ложноотрицательные ошибки: то есть она редко делает ошибочные предсказания о снижении уровня активности, при этом значительно чаще ошибается в предсказаниях сохранения прежнего уровня активности клиентов.**

# %% [markdown]
# ## Анализ важности признаков

# %% [markdown]
# Оценим значимость признаков для модели

# %%
best_model = grid_search.best_estimator_.named_steps['models']
preprocessor = grid_search.best_estimator_.named_steps['preprocessor']

# %%
feature_names = []
for name, transformer, cols in preprocessor.transformers_:
    if name == 'ohe':
        ohe = transformer.named_steps['ohe']
        feature_names.extend(ohe.get_feature_names_out(cols))
    else:
        feature_names.extend(cols)
feature_names
# Out:
# ['тип_сервиса_стандарт',
#  'популярная_категория_Косметика и аксесуары',
#  'популярная_категория_Кухонная посуда',
#  'популярная_категория_Мелкая бытовая техника и электроника',
#  'популярная_категория_Техника для красоты и здоровья',
#  'популярная_категория_Товары для детей',
#  'разрешить_сообщать',
#  'маркет_актив_6_мес',
#  'маркет_актив_тек_мес',
#  'длительность',
#  'акционные_покупки',
#  'средний_просмотр_категорий_за_визит',
#  'неоплаченные_продукты_штук_квартал',
#  'ошибка_сервиса',
#  'страниц_за_визит',
#  'выручка_предыдущий_месяц',
#  'выручка_препредыдущий_месяц',
#  'выручка_текущий_месяц',
#  'минуты_предыдущий_месяц',
#  'минуты_текущий_месяц']

# %% [markdown]
# Рассмотрим коэффициенты модели логистической регрессии

# %%
feature_importance = pd.DataFrame({
    'Feature': feature_names,
    'Importance': np.abs(best_model.coef_[0])
}).sort_values('Importance', ascending=False)

feature_importance
# Out:
#                                               Feature  Importance
# 14                                   страниц_за_визит    1.440518
# 18                            минуты_предыдущий_месяц    1.347257
# 10                                  акционные_покупки    1.254454
# 11                средний_просмотр_категорий_за_визит    1.223463
# 19                               минуты_текущий_месяц    1.183360
# 12                 неоплаченные_продукты_штук_квартал    1.044672
# 7                                  маркет_актив_6_мес    0.967895
# 16                        выручка_препредыдущий_месяц    0.888812
# 3   популярная_категория_Мелкая бытовая техника и ...    0.617163
# 13                                     ошибка_сервиса    0.313910
# 4   популярная_категория_Техника для красоты и здо...    0.245023
# 9                                        длительность    0.186238
# 1          популярная_категория_Косметика и аксесуары    0.162310
# ...

# %% [markdown]
# Построим графики важности признаков с помощью SHAP

# %%
best_model.classes_
# Out:
# array(['Прежний уровень', 'Снизилась'], dtype=object)

# %%
X_train_transformed = preprocessor.transform(X_train)
explainer = shap.LinearExplainer(best_model, X_train_transformed, feature_names=feature_names)
shap_values = explainer(X_train_transformed)

# %%
shap.summary_plot(shap_values, plot_size=(16, 8), show=False)
fig, ax = plt.gcf(), plt.gca()
ax.set_title('Влияние признаков на предсказания модели', fontdict={"size": 16})
ax.set_xlabel('Вклад признака (SHAP value)', fontsize=14)
plt.show()

# %%
shap.summary_plot(shap_values, plot_size=(16, 8), plot_type='bar', show=False)
fig, ax = plt.gcf(), plt.gca()
ax.set_title('Усредненное влияние признаков на предсказания модели', fontdict={"size": 16})
ax.set_xlabel('Средний вклад признака (SHAP value)', fontsize=14)
plt.show()

# %% [markdown]
# <strong>
# Наименее значимыми признаками являются `выручка_текущий_месяц`, `маркет_актив_тек_мес`, `разрешить_сообщать` и `тип_сервиса`.
# Также не очень значительное влияние оказывают признаки `ошибка_сервиса`, `выручка_предыдущий_месяц` и `длительность`.
#
# Наиболее значимы признаки `средний_просмотр_категорий_за_визит`, `страниц_за_визит`, `минуты_предыдущий_месяц`, `минуты_текущий_месяц`, `акционные_покупки`, и `неоплаченные_продукты_штук_квартал`. Значимое влияние также оказывают признаки `выручка_препредыдущий_месяц` и `маркет_актив_6_мес`.
#
# Отдельного внимания заслуживает категория товаров. Можем наблюдать, что категория `Мелкая бытовая техника и электроника` оказывает значимое влияние на целевой признак, а `Техника для красоты и здоровья` хоть и менее значимое, но все еще заметное влияние. Остальные категории не оказывают существенного влияния на целевой признак.
#
# Имеет смысл проверить гипотезы:
# - устранение наименее значимых признаков повысит качество модели.
# - разделение категорий товаров на две (техника / не техника) повысит качество модели.
#
# Рассматривая влияние наиболее значимых признаков на целевой, наблюдаем:
# <ul style="line-height: 2;">
# <li> высокое количество просмотренных категорий за визит, страниц и потраченных на просмотр минут понижает вероятность снижения покупательской активности. То есть у более активных пользователей вероятность снижения покупателськой активности ниже.
#
# <li> высокое значение маректинговой активности также снижает вероятность снижения покупательской активности
#
# <li> низкие значения доли акционных покупок снижают вероятность снижения покупателськой активости. При этом можно заметить сегмент покупателей, совершающих покупки преимуществено по акции - для данного сегмента существенно повышается вероятность снижения покупательской актвиности
#
# <li> высокие значения выручки за позапрошлый месяц снижают вероятность снижения покупательской активности
#
# <li> высокие значения выручки за прошлый месяц, наоборот, немного повышают вероятность снижения покупателськой активности
#
# <li> чем дольше клиент зарегистрирован в сервисе, тем выше вероятность снижения покупательской активности
#
# <li> увеличение количества ошибок сервиса немного увеличивает вероятность снижения покупательской активности
#
# <li> преобладание в просматриваемых категориях техники снижает вероятность снижения покупательской активности
#
# <li> большое количество неоплаченных товаров в корзине повышает вероятность снижения покупательской активности
# </ul>
# </strong>

# %% [markdown]
# ## Сегментация покупателей

# %% [markdown]
# Добавим к датафрейму информацию о прибыли и предсказанные вероятности снижения покупательской активности

# %%
common_df = common_df.join(income_df.set_index('id'), how='left')

# %%
common_df['вероятность_снижения_активности'] = best_model.predict_proba(
    preprocessor.transform(common_df.drop('покупательская_активность', axis=1))
)[:, 1]
common_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1296 entries, 215349 to 216647
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   покупательская_активность            1296 non-null   object
#  1   тип_сервиса                          1296 non-null   object
#  2   разрешить_сообщать                   1296 non-null   object
#  3   маркет_актив_6_мес                   1296 non-null   float64
#  4   маркет_актив_тек_мес                 1296 non-null   int64
#  5   длительность                         1296 non-null   int64
#  6   акционные_покупки                    1296 non-null   float64
#  7   популярная_категория                 1296 non-null   object
#  8   средний_просмотр_категорий_за_визит  1296 non-null   int64
#  9   неоплаченные_продукты_штук_квартал   1296 non-null   int64
#  10  ошибка_сервиса                       1296 non-null   int64
# ...

# %% [markdown]
# Построим диаграмму рассеяния, отображающую связь между прибылью и вероятностью снижения покупательской активности

# %%
plt.figure(figsize=(16, 10))
sns.scatterplot(data=common_df, x='вероятность_снижения_активности', y='прибыль')
plt.title(f'Зависимость прибыли от вероятности снижения активности')
plt.show()

# %% [markdown]
# Видим, что слева график более плотный, то есть преобладают клиенты с низкой вероятностью снижения покупательской активности. При этом дисперсия прибыли относительно равномерна - какой-то закономерности между вероятностью снижения покупательской активности и прибылью не прослеживается.
#
# Также можно заметить небольшое уплотнение графика при вероятности снижения аткивности выше 0.6 и прибылью около 4 у.е. и выше - имеет смысл рассмотреть их как отдельный сегмент клиентов.

# %% [markdown]
# С учетом анализа SHAP значений и прибыльности покупателей, можем выделить следующие сегменты покупателей
# - покупатели, совершающие покупки преимущественно по акции (имеют более высокую вероятность снижения покупательской активности)
# - покупатели, покупающие технику (имеют более низкую вероятность снижения покупательской активности)
# - покупатели, покупающие товары, не относящиеся к категории техники
# - покупатели, имеющие высокую вероятность снижения покупательской активности, при этом приносящие высокую прибыль
# - покупатели с высоким средним количеством неоплаченых товаров в корзине

# %% [markdown]
# Отдельно рассмотрим группу клиентов,  совершающих покупки преимущественно по акции

# %%
auction_df = common_df[common_df['акционные_покупки'] > 0.8]
auction_df.shape
# Out:
# (164, 19)

# %%
draw_bar(
    auction_df['покупательская_активность'],
    title='Распределение по покупательской активности',
    label='Покупательская активность',
)

# %%
draw_hist(
    auction_df['прибыль'],
    title='Распределение прибыли',
    xlabel='Прибыль, у.е.',
    bins=20
)

# %%
draw_bar(
    auction_df['популярная_категория'],
    title='Распределение по самым популярным категориям',
    label='Самая популярная категория',
    horizontal=True,
    ascending=True,
)

# %% [markdown]
#     Наблюдаем, что у клиентов, покупающих товары преимущественно по акции, наиболее популярны товары для детей, при этом их популярность по отношению к другим категорям значительно более выражена, чем среди клиентов в целом

# %% [markdown]
# Для рассматриваемого сегмента построим диаграмму рассеяния, отображающую связь между прибылью и вероятностью снижения покупательской активности

# %%
plt.figure(figsize=(16, 10))
sns.scatterplot(data=auction_df, x='вероятность_снижения_активности', y='прибыль')
plt.title(f'Зависимость прибыли от вероятности снижения активности')
plt.show()

# %% [markdown]
# Видим, что у данного сегмента плотность графика ожидаемо более высокая справа (преобладают клиенты с высокой вероятностью снижения покупательской активности). При этом зависимость между прибылью и вероятностью снижения покупательской активности не прослеживается.

# %% [markdown]
# Построим диаграммы рассеяния зависимости прибыли от наиболее значимых числовых признаков с учетом целевого признака

# %%
def scatterplot_income(
    df: pd.DataFrame,
    x: str,
) -> None:
    plt.figure(figsize=(10, 5))
    sns.scatterplot(data=df, x=x, y='прибыль', hue='покупательская_активность')
    plt.title(f'Зависимость прибыли от {x}')
    plt.show()

# %%
display(HTML("<style>.output_scroll {height: auto !important;}</style>"))
for feature in (
    'маркет_актив_6_мес', 'средний_просмотр_категорий_за_визит', 'страниц_за_визит',
    'минуты_предыдущий_месяц', 'минуты_текущий_месяц', 'неоплаченные_продукты_штук_квартал',
    'выручка_препредыдущий_месяц',
):
    scatterplot_income(auction_df, feature)
# Out:
# <style>.output_scroll {height: auto !important;}</style>

# %% [markdown]
# Наблюдаются уже ранее выявленные закономерности в распределении целевого признака. Что касается размера прибыли, то наблюдается относительно равномерная дисперсия в распределении прибыли

# %% [markdown]
# Построим гистограмму распределения прибыли для выделенного сегмента клиентов

# %%
draw_hist(
    auction_df['прибыль'],
    title='Распределение прибыли',
    xlabel='Прибыль, у.е.',
    bins=20
)

# %% [markdown]
# В отличие от гистограммы по всем пользовавтелям, очертания нормального распределения менее выраженны, однако это объясняется меньшим размером выборки

# %% [markdown]
# **В целом у сегмента клиентов, покупающих товары преимущественно по акции,  наблюдаются уже ранее выявленные закономерности.
# Для увеличения покупательской активности имеет смысл увеличить количество маркетинговых коммуникаций до 4-5 в месяц.**

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В качестве источника информации использовались данные о поведении покупателей на сайте, о коммуникациях с покупателем и его продуктовом поведении, о выручке и прибыли с покупателя.
#
# В данных отсуствовали явные дубликаты и пропуски. Были обнаружены и устранены неявные дубликаты.
#
# Для предсказания целевого признака были обучены 4 типа моделей - логистическая регрессия, дерево решений, метод опорных векторов и knn. В качестве метрики была выбрана ROC-AUC для общей оценки качества модели, поскольку отсутствует информация, на основе которой можно было бы сделать вывод о приоритетном типе ошибок. Лучше всего себя зарекомендовала модель логистической регрессии с l2-регуляризацией - на тестовой выборке она показала значение метрики 0.92.
#
# Анализ влияния признаков на целевой показал, что наибольшее влияние на вероятность снижения покупательской активности оказывает активность клиента на сайте, доля покупок по акции, количество неоплаченных товаров в корзине, количество маркетинговых коммуникаций с клиентом и выручка за позапрошлый месяц. При этом вероятность снижения покупательской активности ниже у активных пользователей сайта, пользователей с высоким количеством маркетинговых коммуникаций и высокими значениями выручки за позапрошлый месяц, а также пользователей, у которых наиболее популярными категориями является техника. Высокие значения покупок по акции и количества неоплаченных товаров в корзине, наоборот, повышают вероятность снижения покупательской активности. Менее значительное влияние на снижение покупательской активности оказывают более высокие значения количества ошибок на сайте, количества дней с момента регистрации и выручки прошлого месяца.
#
# С учетом выявленных закономерностей, можно выделить следующие сегменты покупателей:
# - покупатели, совершающие покупки преимущественно по акции (имеют более высокую вероятность снижения покупательской активности)
# - покупатели, покупающие технику (имеют более низкую вероятность снижения покупательской активности)
# - покупатели, покупающие товары, не относящиеся к категории техники
# - покупатели, имеющие высокую вероятность снижения покупательской активности, при этом приносящие высокую прибыль
# - покупатели с высоким средним количеством неоплаченных товаров в корзине
#
# Отдельный анализ сегмента покупателей, совершающих покупки преимущественно по акции, показал, что для этого сегмента характерны общие выявленные закономерности.
#
# Для уменьшения вероятности снижения покупательской активности рекомендуется увеличить количество маректинговых коммуникаций до 4-5 в месяц.
